# %%
chr(0).__repr__()
# Out:
# "'\\x00'"

# %%
''.__repr__()
# Out:
# "''"

# %%
test_string = "hello! こんにちは!"

# %%
list(test_string.encode('utf-8'))
# Out:
# [104,
#  101,
#  108,
#  108,
#  111,
#  33,
#  32,
#  227,
#  129,
#  147,
#  227,
#  130,
#  147,
#  227,
#  129,
#  171,
#  227,
#  129,
#  161,
#  227,
#  129,
#  175,
#  33]

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
 return "".join([bytes([b]).decode("utf-8") for b in bytestring])

# %%
decode_utf8_bytes_to_str_wrong('hello'.encode('utf-8'))
# Out:
# 'hello'

# %%
bytes([255,255]).decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 bytes([255,255]).decode('utf-8')
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
import regex as re
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

# %%
type(PAT)
# Out:
# str

# %%
# ?re.Match
# Out:
# Init signature: re.Match()
# Docstring:      Match object
# Type:           type
# Subclasses:

# %%
for t in re.finditer(PAT, "some text that i'll pre-tokenize"):
    print(type(t.group()))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
import multiprocess
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 import multiprocess
#
# ModuleNotFoundError: No module named 'multiprocess'

# %%
# ?multiprocessing.map
# Out:
# Object `multiprocessing.map` not found.
